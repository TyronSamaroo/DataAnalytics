# %% [markdown]
# ## HomeWork 2 EDA, Data Visualization and Linear Regression Model

# %% [markdown]
# # Due on 9/30/2019 mid-night

# %% [markdown]
# ## Late Policy: Take off 50% after one day, 80% after two days

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading our MPG3 dataset

# %%
mpg = pd.read_csv("mpg3.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.shape
# Out:
# (405, 9)

# %% [markdown]
# # Question 1: Check to see if there are any missing values. Fix the missing values by imputing value from the mean. After fixing missing values, you should still have 405 rows

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower        weight  \
# count  404.000000  405.000000    405.000000  399.000000    404.000000
# mean    23.645545    5.493827    194.504938  105.593985   3020.866337
# std      8.465607    1.847687    105.231828   42.317959   1282.513294
# min      9.000000    3.000000     68.000000   46.000000   1613.000000
# 25%     17.000000    4.000000    105.000000   76.000000   2227.500000
# 50%     23.000000    4.000000    151.000000   95.000000   2803.500000
# 75%     29.000000    8.000000    267.000000  129.000000   3614.750000
# max     90.000000   20.000000    455.000000  450.000000  22340.000000
#
#        acceleration  model_year
# count    405.000000  405.000000
# mean      15.521481   75.987654
# std        2.792380    3.746595
# min        8.000000   70.000000
# 25%       13.800000   73.000000
# 50%       15.500000   76.000000
# 75%       17.100000   79.000000
# max       24.800000   85.000000

# %%
mpg.isnull().any()
# Out:
# mpg              True
# cylinders       False
# displacement    False
# horsepower       True
# weight           True
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
#Fix the True places with missing values with the mean
mpg['mpg'] = mpg['mpg'].fillna(mpg['mpg'].mean())
mpg['horsepower'] = mpg['horsepower'].fillna(mpg['horsepower'].mean())
mpg['weight'] = mpg['weight'].fillna(mpg['weight'].mean())

# %%
mpg.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
mpg.shape
# Out:
# (405, 9)

# %% [markdown]
# # Question 2 : Use Boxplot to see if there are any outliers on ALL of the numerical fields (Hint you should have 402 rows now after outliers removal)

# %%
#Not sure why rest of col not showing up
print(mpg.describe())
print(mpg.shape)
# Out:
#               mpg   cylinders  displacement  horsepower        weight  \
# count  405.000000  405.000000    405.000000  405.000000    405.000000
# mean    23.645545    5.493827    194.504938  105.593985   3020.866337
# std      8.455124    1.847687    105.231828   42.002541   1280.925042
# min      9.000000    3.000000     68.000000   46.000000   1613.000000
# 25%     17.000000    4.000000    105.000000   76.000000   2228.000000
# 50%     23.000000    4.000000    151.000000   95.000000   2807.000000
# 75%     29.000000    8.000000    267.000000  125.000000   3613.000000
# max     90.000000   20.000000    455.000000  450.000000  22340.000000
#
#        acceleration  model_year
# count    405.000000  405.000000
# mean      15.521481   75.987654
# std        2.792380    3.746595
# min        8.000000   70.000000
# 25%       13.800000   73.000000
# 50%       15.500000   76.000000
# 75%       17.100000   79.000000
# max       24.800000   85.000000
# (405, 9)

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.boxplot(x=mpg['mpg'])
plt.show()
sns.boxplot(x=mpg['cylinders'])
plt.show()
sns.boxplot(x=mpg['displacement'])
plt.show()
sns.boxplot(x=mpg['horsepower'])
plt.show()
sns.boxplot(x=mpg['weight'])
plt.show()
sns.boxplot(x=mpg['acceleration'])
plt.show()
sns.boxplot(x=mpg['model_year'])
plt.show()

# %%
sns.scatterplot(x='mpg', y='mpg' ,data = mpg)
plt.show()
sns.scatterplot(x='cylinders', y='cylinders' ,data = mpg)
plt.show()
sns.scatterplot(x='displacement', y='displacement' ,data = mpg)
plt.show()
sns.scatterplot(x='horsepower', y='horsepower' ,data = mpg)
plt.show()
sns.scatterplot(x='weight', y='weight' ,data = mpg)
plt.show()
sns.scatterplot(x='acceleration', y='acceleration' ,data = mpg)
plt.show()
sns.scatterplot(x='model_year', y='model_year' ,data = mpg)
plt.show()

# %%
mpg.shape
# Out:
# (405, 9)

# %%
mpg = mpg[mpg.mpg < 60]
mpg = mpg[mpg.horsepower < 300]
mpg = mpg[mpg.weight < 10000 ]
mpg = mpg[mpg.cylinders < 12.5]

# %%
mpg.shape
# Out:
# (402, 9)

# %% [markdown]
# # Question 3 : Remove any duplicates rows. Hint after removal, you should have 400 rows now

# %%
# Show number of rows before
print("Before duplicates removal: ", mpg.shape)

# Type your code here to remove duplicated rows
# Replace is find duplicates
mpg.drop_duplicates(inplace = True) 

# hint: Google how to remove duplicate rows in pandas dataframe and you will find the link
# https://pandas.pydata.org/pandas-docs/version/0.17/generated/pandas.DataFrame.drop_duplicates.html

# Show number of rows before
print("After duplicates removal: ", mpg.shape)
# Out:
# Before duplicates removal:  (400, 9)
# After duplicates removal:  (400, 9)

# %% [markdown]
# # Question 4: Create a pair plot

# %%
# Type your code here
sns.pairplot(mpg)

# %% [markdown]
# # Question 5: Create a FacetGrid of a scatter plot of mpg vs weight for different country

# %%
# Type your code here
g = sns.FacetGrid(mpg, col = 'origin')
g = (g.map(plt.scatter, 'mpg', 'weight').add_legend())

# %% [markdown]
# # Now Load the adult income dataset and do some EDA and answer the following questions based on the Adult income dataset

# %%
adult = pd.read_csv("adult.data.csv")
adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
adult.isnull().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# salary            False
# dtype: bool

# %%
print(adult.shape)
adult.describe()
# Out:
# (32561, 15)
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Question 6 : Which two martial-status is most common

# %% [markdown]
# Most common Marital Status are Never-married and Married-civ-spouse

# %%
print(adult['marital-status'].unique())
print(adult['marital-status'].value_counts())
# Out:
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
adult.groupby(['marital-status']).describe()
# Out:
#                            age                                                \
#                          count       mean        std   min   25%   50%   75%
# marital-status
# Divorced                4443.0  43.041639  10.400396  18.0  35.0  42.0  50.0
# Married-AF-spouse         23.0  32.478261  11.610613  19.0  26.5  30.0  35.0
# Married-civ-spouse     14976.0  43.247596  12.056002  17.0  34.0  42.0  51.0
# Married-spouse-absent    418.0  40.578947  12.397677  18.0  31.0  40.0  48.0
# Never-married          10683.0  28.150988  10.007241  17.0  21.0  25.0  32.0
# Separated               1025.0  39.354146  10.835977  18.0  31.0  38.0  46.0
# Widowed                  993.0  58.975831  12.345555  18.0  51.0  60.0  67.0
#
#                               fnlwgt                 ... capital-loss          \
#                         max    count           mean  ...          75%     max
# marital-status                                       ...
# Divorced               90.0   4443.0  185802.790457  ...          0.0  3900.0
# Married-AF-spouse      75.0     23.0  188165.565217  ...          0.0     0.0
# Married-civ-spouse     90.0  14976.0  186763.172877  ...          0.0  2603.0
# Married-spouse-absent  80.0    418.0  193141.760766  ...          0.0  2472.0
# Never-married          90.0  10683.0  195383.308996  ...          0.0  3683.0
# Separated              90.0   1025.0  206444.325854  ...          0.0  3900.0
# Widowed                90.0    993.0  174159.042296  ...          0.0  4356.0
#
#                       hours-per-week                                         \
#                                count       mean        std  min   25%   50%
# marital-status
# Divorced                      4443.0  41.246680  10.676632  1.0  40.0  40.0
# Married-AF-spouse               23.0  41.130435  19.440596  3.0  39.0  40.0
# Married-civ-spouse           14976.0  43.284856  11.905047  1.0  40.0  40.0
# Married-spouse-absent          418.0  39.669856  11.767374  3.0  37.0  40.0
# Never-married                10683.0  36.939998  12.432542  1.0  30.0  40.0
# Separated                     1025.0  39.301463  10.377534  2.0  37.0  40.0
# Widowed                        993.0  32.979859  14.058690  1.0  21.0  40.0
#
#
#                         75%   max
# marital-status
# Divorced               45.0  99.0
# Married-AF-spouse      47.0  90.0
# Married-civ-spouse     50.0  99.0
# Married-spouse-absent  40.0  99.0
# Never-married          40.0  99.0
# Separated              40.0  99.0
# Widowed                40.0  99.0
#
# [7 rows x 48 columns]

# %%
adult.groupby(['marital-status']).count()
# Out:
#                          age  workclass  fnlwgt  education  education-num  \
# marital-status
# Divorced                4443       4443    4443       4443           4443
# Married-AF-spouse         23         23      23         23             23
# Married-civ-spouse     14976      14976   14976      14976          14976
# Married-spouse-absent    418        418     418        418            418
# Never-married          10683      10683   10683      10683          10683
# Separated               1025       1025    1025       1025           1025
# Widowed                  993        993     993        993            993
#
#                        occupation  relationship   race    sex  capital-gain  \
# marital-status
# Divorced                     4443          4443   4443   4443          4443
# Married-AF-spouse              23            23     23     23            23
# Married-civ-spouse          14976         14976  14976  14976         14976
# Married-spouse-absent         418           418    418    418           418
# Never-married               10683         10683  10683  10683         10683
# Separated                    1025          1025   1025   1025          1025
# Widowed                       993           993    993    993           993
#
#                        capital-loss  hours-per-week  native-country  salary
# marital-status
# Divorced                       4443            4443            4443    4443
# Married-AF-spouse                23              23              23      23
# Married-civ-spouse            14976           14976           14976   14976
# Married-spouse-absent           418             418             418     418
# Never-married                 10683           10683           10683   10683
# Separated                      1025            1025            1025    1025
# Widowed                         993             993             993     993

# %% [markdown]
# # Question 7: Plot the age distribution broken down by different martial-status using a FacetGrid

# %%
print(adult['sex'].value_counts())
print(adult['race'].value_counts())
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Type your code here
g = sns.FacetGrid(adult, col = 'marital-status')
g = g.map(plt.hist, 'age')

# %% [markdown]
# # Question 8: Create a Facet Grid for fnlwgt against age broken down by race and sex. You should have 10 sub-plots

# %%
# Type your code here
# Theres only 5 races and 2 sex I got only 7 plots.
g = sns.FacetGrid(adult, col='race')
g = (g.map(plt.scatter, "fnlwgt", "age").add_legend())

# %%
g = sns.FacetGrid(adult, col='sex')
g = (g.map(plt.scatter, "fnlwgt", "age").add_legend())

# %% [markdown]
# # Now Load the housing data and answer all the remaining questions based on the housing dataset

# %%
housing = pd.read_csv("USA_housing.csv")
housing.head()
# Out:
#         Income  HouseAge  NumberOfRooms  AreaNumberOfBedrooms   Population  \
# 0  79545.45857  5.682861       7.009188                  4.09  23086.80050
# 1  79248.64245  6.002900       6.730821                  3.09  40173.07217
# 2  61287.06718  5.865890       8.512727                  5.13  36882.15940
# 3  63345.24005  7.188236       5.586729                  3.26  34310.24283
# 4  59982.19723  5.040555       7.839388                  4.23  26354.10947
#
#           Price                                            Address
# 0  1.059034e+06  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  1.505891e+06  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  1.058988e+06  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3  1.260617e+06                          USS Barnett\nFPO AP 44820
# 4  6.309435e+05                         USNS Raymond\nFPO AE 09386

# %%
# a scatter plot comparing num_children and num_pets
housing.plot(kind='scatter',x='Income',y='Price',color='blue')
plt.show()

# %%
housing.plot(kind='scatter', x = "HouseAge", y = "Price", color = "blue")

# %%
housing.plot(kind='scatter', x = "NumberOfRooms", y = "Price", color = "green")

# %% [markdown]
# # Question 9: Use a pair plot or individual scatter plots, pick ONE variable that best explains house price

# %% [markdown]
# # Type your answer (ie which variable affect the Price the most)
# I think one variable that best explain house prices is based on the income area. I would assume the higher the income in a certain area the higher the cost of homes would be.

# %%
sns.pairplot(data = housing)

# %% [markdown]
# # Question 10:  Use that variable to build a one-variable Linear Regression model of the house price. Make sure you split the data between Training and Testing set first, Save 20% as your testing data

# %%
adult.shape
# Out:
# (32561, 15)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
Xarray = housing['Price'].values
Yarray = housing['Income'].values

# %%
X = housing['Price'].values.reshape(-1,1)
Y = housing['Income'].values.reshape(-1,1)

# %%
model1.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model1.intercept_)
print(model1.coef_)
# Out:
# [44793.26675365]
# [[0.0193088]]

# %%
Y_pred = model1.predict(X)

# %%
plt.scatter(X, Y,  color='gray')
plt.plot(X, Y_pred, color='red', linewidth=2)
plt.show()

# %%
# Show your work here
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y , test_size = 0.5, random_state = 0)

# %%
print(housing.Price.shape)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(0.8 * housing.shape[0])
# Out:
# (5000,)
# (2500, 1)
# (2500, 1)
# (2500, 1)
# (2500, 1)
# 4000.0

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = model.predict(X_test)

# %%
print(model1.intercept_)
print(model1.coef_)
print()
print(model.intercept_)
print(model.coef_)
# Out:
# [44793.26675365]
# [[0.0193088]]
#
# [44916.23085147]
# [[0.01936732]]

# %%
plt.scatter(X_test, Y_test,  color='gray')
plt.scatter(X_test, Y_pred, color='red', linewidth=2)
plt.show()

# %%
# Show your R-square and RMSE
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Root Mean Squared Error: 8210.969764260155
# R-squared: 0.41172513344842254

# %% [markdown]
# # Question 11: Now do a 10-fold Cross Validation of your model. Does your model pass cross validation?

# %%
import random
for i in range(10):
    print(random.randint(1, 1000))
# Out:
# 152
# 982
# 230
# 304
# 882
# 316
# 717
# 758
# 233
# 879

# %%
# Show your work here
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y , test_size = 0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    print('Trial {}, R-squared: {},  Slope: {}, Intercept: {},  '.format(i, metrics.r2_score(Y_test, Y_pred), \
                                                                      model.coef_, model.intercept_))

    plt.scatter(X_test, Y_test,  color='gray')
    plt.scatter(X_test, Y_pred, color='red', linewidth=2)
    plt.show()
# Out:
# Trial 0, R-squared: 0.4286992642000278,  Slope: [[0.01897764]], Intercept: [45209.02309019],
# Trial 1, R-squared: 0.41579952505963114,  Slope: [[0.0193429]], Intercept: [44713.32803046],
# Trial 2, R-squared: 0.41498114109126794,  Slope: [[0.01916022]], Intercept: [44950.15939179],
# Trial 3, R-squared: 0.3786627581392824,  Slope: [[0.01960064]], Intercept: [44443.96784997],
# Trial 4, R-squared: 0.4083213590120036,  Slope: [[0.01939668]], Intercept: [44747.86227593],
# Trial 5, R-squared: 0.4237286035385984,  Slope: [[0.01935289]], Intercept: [44788.95855851],
# Trial 6, R-squared: 0.40749090678934574,  Slope: [[0.01933797]], Intercept: [44747.76108047],
# Trial 7, R-squared: 0.4431831627861288,  Slope: [[0.01919131]], Intercept: [44865.15074911],
# Trial 8, R-squared: 0.43379365651605084,  Slope: [[0.01907848]], Intercept: [45039.01241261],
# Trial 9, R-squared: 0.41456801084698314,  Slope: [[0.01943254]], Intercept: [44553.49472171],

# %%
rsquare = []
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    rsquare.append(metrics.r2_score(Y_test, Y_pred))
    
rdf = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
rdf
# Out:
#    trial   Rsquare
# 0      0  0.444249
# 1      1  0.404930
# 2      2  0.410541
# 3      3  0.405387
# 4      4  0.385502
# 5      5  0.391933
# 6      6  0.428621
# 7      7  0.426988
# 8      8  0.420234
# 9      9  0.418490

# %%
print(rdf['Rsquare'].mean())
# Out:
# 0.41368751190896924

# %% [markdown]
# # Question 12: Now pick ONE more variable in addition to the variable you choose from Question 9 and build a two-variables Linear Regression model of the house price. Make sure you split the data into training and testing set first

# %%
# Show your work here
X = housing[['Income','NumberOfRooms']].values.reshape(-1,2)
Y= housing['Price'].values.reshape(-1,1)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (4000, 2) (1000, 2)
# (4000, 1) (1000, 1)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print(model.coef_)
print(model.intercept_)
# Out:
# [[2.14627538e+01 1.18628849e+05]]
# [-1068549.32552966]

# %%
plt.scatter(Y_test, Y_pred, color='red', linewidth=2)
plt.show()

# %%
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# R-squared: 0.5284933012232391

# %% [markdown]
# # Question 13: Do a 10-fold Cross Validation of your two-variable model. Does your model pass cross validation?

# %%
# Show your work here
rsquare = []
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    rsquare.append(metrics.r2_score(Y_test, Y_pred))
    print('Trial {}, R-squared: {},  Slope: {}, Intercept: {},  '.format(i, metrics.r2_score(Y_test, Y_pred), \
                                                                      model.coef_, model.intercept_))

    
rdf = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
rdf.plot.bar(x='trial', y='Rsquare')
a = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
a
# Out:
# Trial 0, R-squared: 0.5221507976382199,  Slope: [[2.13930704e+01 1.18785369e+05]], Intercept: [-1063787.65540712],
# Trial 1, R-squared: 0.5119262473847892,  Slope: [[2.13830180e+01 1.22234988e+05]], Intercept: [-1090607.69692879],
# Trial 2, R-squared: 0.5164993084960827,  Slope: [[2.13526970e+01 1.20566124e+05]], Intercept: [-1073382.50789796],
# Trial 3, R-squared: 0.5174108130332548,  Slope: [[2.11966484e+01 1.19971300e+05]], Intercept: [-1059377.91226948],
# Trial 4, R-squared: 0.5050221177816134,  Slope: [[2.14109128e+01 1.22996687e+05]], Intercept: [-1097117.63710969],
# Trial 5, R-squared: 0.5237522019001126,  Slope: [[2.12878306e+01 1.21947867e+05]], Intercept: [-1081423.38387551],
# Trial 6, R-squared: 0.5384587984574696,  Slope: [[2.11955233e+01 1.21840168e+05]], Intercept: [-1072780.02680797],
# Trial 7, R-squared: 0.48840923448724416,  Slope: [[2.15861591e+01 1.21465237e+05]], Intercept: [-1098137.47561411],
# Trial 8, R-squared: 0.5025513932160088,  Slope: [[2.17804237e+01 1.21628892e+05]], Intercept: [-1112497.30246745],
# Trial 9, R-squared: 0.5398413347101692,  Slope: [[2.13142871e+01 1.23176532e+05]], Intercept: [-1092225.92224386],
#    trial   Rsquare
# 0      0  0.522151
# 1      1  0.511926
# 2      2  0.516499
# 3      3  0.517411
# 4      4  0.505022
# 5      5  0.523752
# 6      6  0.538459
# 7      7  0.488409
# 8      8  0.502551
# 9      9  0.539841

# %%
print(rdf['Rsquare'].mean())
# Out:
# 0.5166022247104964

# %% [markdown]
# Yes my Model Passes Cross Validation
